# %%
# This notebook is useless
import sys
from pathlib import Path

# notebooks/ -> go up one level to repo root
project_root = Path().resolve().parent
third_party_path = project_root / "src" / "python" / "adamp" / "third_party"
sys.path.insert(0, str(third_party_path))

from stability_selection.stability_selection import StabilitySelection, plot_stability_path
